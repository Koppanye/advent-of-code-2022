# %%
#17. feladat:

def make_move(head_posi, tail_posi, direction):
    if head_posi[0] == tail_posi[0] and head_posi[1] == tail_posi[1] + 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = [tail_posi[0], tail_posi[1] + 1]
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] + 1 and head_posi[1] == tail_posi[1] + 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = [tail_posi[0] + 1, tail_posi[1] + 1]
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = [tail_posi[0] + 1, tail_posi[1] + 1]
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] + 1 and head_posi[1] == tail_posi[1]:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = [tail_posi[0] + 1, tail_posi[1]]
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] + 1 and head_posi[1] == tail_posi[1] - 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = [tail_posi[0] + 1, tail_posi[1] - 1]
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = [tail_posi[0] + 1, tail_posi[1] - 1]
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] and head_posi[1] == tail_posi[1] - 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = [tail_posi[0], tail_posi[1] - 1]
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] - 1 and head_posi[1] == tail_posi[1] - 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = [tail_posi[0] - 1, tail_posi[1] - 1]
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = [tail_posi[0] - 1, tail_posi[1] - 1]
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] - 1 and head_posi[1] == tail_posi[1]:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = [tail_posi[0] - 1, tail_posi[1]]
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] - 1 and head_posi[1] == tail_posi[1] + 1:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = [tail_posi[0] - 1, tail_posi[1] + 1]
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = [tail_posi[0] - 1, tail_posi[1] + 1]
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        
    if head_posi[0] == tail_posi[0] and head_posi[1] == tail_posi[1]:
        if direction == 'R':
            new_head = [head_posi[0] + 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'L':
            new_head = [head_posi[0] - 1, head_posi[1]]
            new_tail = tail_posi
            return [new_head, new_tail] 
        if direction == 'U':
            new_head = [head_posi[0], head_posi[1] + 1]
            new_tail = tail_posi
            return [new_head, new_tail]
        if direction == 'D':
            new_head = [head_posi[0], head_posi[1] - 1]
            new_tail = tail_posi
            return [new_head, new_tail]
unique_tail = [[0,0]]
head_pos = [[0,0]]
tail_pos = [[0,0]]
steps = []
with open('17_feladat.txt', 'r') as f:
    line = f.readline().strip().split()
    while line:
        
        direction = line[0]
        num_of_steps = int(line[1])
        steps += [direction for i in range(num_of_steps)]

        line = f.readline().strip().split()
    
    
    for s in steps:
        new_pos = make_move(head_pos[-1], tail_pos[-1], s)
        head_pos.append(new_pos[0])
        tail_pos.append(new_pos[1])
        if new_pos[1] not in unique_tail:
            unique_tail.append(new_pos[1])

    
    print(len(unique_tail))
# Out:
# 11451
# 5735

# %%
def rope_move(h, t):
    if h[0] - t[0] == 2 and h[1] - t[1] == 2:
        return [t[0] + 1, t[1] + 1]
    elif h[0] - t[0] == 2 and h[1] - t[1] == 1:
        return [t[0] + 1, t[1] + 1]
    elif h[0] - t[0] == 2 and h[1] - t[1] == 0:
        return [t[0] + 1, t[1]]
    elif h[0] - t[0] == 2 and h[1] - t[1] == -1:
        return [t[0] + 1, t[1] - 1]
    elif h[0] - t[0] == 2 and h[1] - t[1] == -2:
        return [t[0] + 1, t[1] - 1]
    elif h[0] - t[0] == 1 and h[1] - t[1] == 2:
        return [t[0] + 1, t[1] + 1]
    elif h[0] - t[0] == 1 and h[1] - t[1] == -2:
        return [t[0] + 1, t[1] - 1]
    elif h[0] - t[0] == 0 and h[1] - t[1] == 2:
        return [t[0], t[1] + 1]
    elif h[0] - t[0] == 0 and h[1] - t[1] == -2:
        return [t[0], t[1] - 1]
    elif h[0] - t[0] == -1 and h[1] - t[1] == 2:
        return [t[0] - 1, t[1] + 1]
    elif h[0] - t[0] == -1 and h[1] - t[1] == -2:
        return [t[0] - 1, t[1] - 1]
    elif h[0] - t[0] == -2 and h[1] - t[1] == 2:
        return [t[0] - 1, t[1] + 1]
    elif h[0] - t[0] == -2 and h[1] - t[1] == 1:
        return [t[0] - 1, t[1] + 1]
    elif h[0] - t[0] == -2 and h[1] - t[1] == 0:
        return [t[0] - 1, t[1]]
    elif h[0] - t[0] == -2 and h[1] - t[1] == -1:
        return [t[0] - 1, t[1] - 1]
    elif h[0] - t[0] == -2 and h[1] - t[1] == -2:
        return [t[0] - 1, t[1] - 1]
    else:
        return t
    
print(rope_move([-2,2],[0,0]))
# Out:
# [-1, 1]

# %%
#18. feladat:

rope_pos = [[0,0] for i in range(10)]
tail_sep = [[0,0]]
for s in steps:
    if s == 'U':
        rope_pos[0][1] += 1 
    elif s == 'D':
        rope_pos[0][1] += -1
    elif s == 'R':
        rope_pos[0][0] += 1
    elif s == 'L':
        rope_pos[0][0] += -1
        
    for i in range(9):
        rope_pos[i+1] = rope_move(rope_pos[i], rope_pos[i+1])
        
    if rope_pos[9] not in tail_sep:
        tail_sep.append(rope_pos[9])
        
print(len(tail_sep))
# Out:
# 2478
